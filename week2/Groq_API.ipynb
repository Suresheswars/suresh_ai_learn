# %%
import os
os.environ["GROQ_API_KEY"] = "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"

from groq import Groq
client = Groq(api_key=os.environ.get("GROQ_API_KEY"))

response = client.chat.completions.create(
    model="llama-3.1-70b-versatile",
    messages=[
        {"role": "system", "content": "You are a friendly AI assistant."},
        {"role": "user", "content": "What is tokenization in the context of LLMs?"}
    ],
    temperature=0.7,
    max_tokens=100
)

print("\n📝 Model Response:")
print(response.choices[0].message.content)
print(f"\n📊 Tokens used: {response.usage.total_tokens}")
# Out:
# ---------------------------------------------------------------------------
# GroqError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 from groq import Groq
#       2 import os
#       3
# ----> 4 client = Groq(api_key=os.environ.get("GROQ_API_KEY"))  # Direct API key
#       5
#       6 response = client.chat.completions.create(
#       7     model="llama-3.1-70b-versatile",
#
# File e:\AI\.venv\Lib\site-packages\groq\_client.py:83, in Groq.__init__(self, api_key, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#      81     api_key = os.environ.get("GROQ_API_KEY")
#      82 if api_key is None:
# ---> 83     raise GroqError(
#      84         "The api_key client option must be set either by passing api_key to the client or by setting the GROQ_API_KEY environment variable"
#      85     )
#      86 self.api_key = api_key
#      88 if base_url is None:
#
# GroqError: The api_key client option must be set either by passing api_key to the client or by setting the GROQ_API_KEY environment variable

# %%
pip install groq
# Out:
# Collecting groq
#   Downloading groq-1.6.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in e:\ai\.venv\lib\site-packages (from groq) (4.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in e:\ai\.venv\lib\site-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in e:\ai\.venv\lib\site-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in e:\ai\.venv\lib\site-packages (from groq) (2.13.4)
# Requirement already satisfied: sniffio in e:\ai\.venv\lib\site-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in e:\ai\.venv\lib\site-packages (from groq) (4.16.0)
# Requirement already satisfied: idna>=2.8 in e:\ai\.venv\lib\site-packages (from anyio<5,>=3.5.0->groq) (3.18)
# Requirement already satisfied: certifi in e:\ai\.venv\lib\site-packages (from httpx<1,>=0.23.0->groq) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in e:\ai\.venv\lib\site-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in e:\ai\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\ai\.venv\lib\site-packages (from pydantic<3,>=1.9.0->groq) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in e:\ai\.venv\lib\site-packages (from pydantic<3,>=1.9.0->groq) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in e:\ai\.venv\lib\site-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)
# Downloading groq-1.6.0-py3-none-any.whl (143 kB)
# Installing collected packages: groq
# Successfully installed groq-1.6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
